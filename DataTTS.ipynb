# %% [markdown]
# <a href="https://colab.research.google.com/github/Kither12/CS114.O11-22521494/blob/main/DataTTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install TTS
# !pip install datasets

# %%
from google.colab import auth
auth.authenticate_user()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mf = open("/content/drive/MyDrive/ML005/data.txt", "r+")
file_line = mf.readline()
data = []
cnt = 0
while file_line:
    if file_line != '\n':
      data.append(file_line)
    cnt += 1
    file_line = mf.readline()
mf.close()
data = [line.rstrip('\n') for line in data]
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000

# %%
from TTS.api import TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to('cuda')
# Out:
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
#  | | > y
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2
# 100%|█████████▉| 1.86G/1.87G [00:27<00:00, 80.0MiB/s]
# 100%|██████████| 1.87G/1.87G [00:28<00:00, 65.7MiB/s]
# 100%|██████████| 4.37k/4.37k [00:00<00:00, 8.52kiB/s]
#
# 100%|██████████| 361k/361k [00:00<00:00, 624kiB/s]
# 100%|██████████| 32.0/32.0 [00:00<00:00, 32.4iB/s]
#  64%|██████▎   | 4.93M/7.75M [00:00<00:00, 49.3MiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
#  > Using model: xtts
# 100%|██████████| 7.75M/7.75M [00:19<00:00, 49.3MiB/s]

# %%
len(data)
# Out:
# 5668

# %%
audio = []
text = []
for i in range(3962,5000):
  s = data[i]
  tts.tts_to_file(text=s,
                file_path=f"/content/drive/MyDrive/ML005/AudioFolder/audio/au{i}.wav",
                speaker="Ana Florence",
                language="en",)
  # audio.append(f"audio/au{i}.wav")
  # text.append(s)
# Out:
#  > Text splitted to sentences.
# ['If people run different protocols (for example, if one person has manners but the other does not, or if one understands the concept of time and the other does not) the protocols do not interoperate and no useful work can be accomplished.']
#  > Processing time: 14.74712347984314
#  > Real-time factor: 0.7333518401349124
#  > Text splitted to sentences.
# ['The same is true in networking—it takes two (or more) communicating entities running the same protocol in order to accomplish a task.']
#  > Processing time: 5.102494478225708
#  > Real-time factor: 0.5677735327254585
#  > Text splitted to sentences.
# ['Let’s consider a second human analogy.']
#  > Processing time: 1.4445359706878662
#  > Real-time factor: 0.46242767354337183
#  > Text splitted to sentences.
# ['Suppose you’re in a college class (a computer networking class, for example!).']
#  > Processing time: 2.9386229515075684
#  > Real-time factor: 0.4695408411647963
# ...
